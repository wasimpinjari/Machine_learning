# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('file:///C:/Users/wasim/Downloads/Advertising.csv')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
pd.plotting.scatter_matrix(df,alpha=0.2)
plt.show()

# %%
df.shape
# Out:
# (200, 4)

# %%
df.insert(0,'intercept',np.ones((200,1),dtype='i'))

# %%
df.head()
# Out:
#    intercept     TV  Radio  Newspaper  Sales
# 0          1  230.1   37.8       69.2   22.1
# 1          1   44.5   39.3       45.1   10.4
# 2          1   17.2   45.9       69.3    9.3
# 3          1  151.5   41.3       58.5   18.5
# 4          1  180.8   10.8       58.4   12.9

# %%
x=df.iloc[ : , 0:4].values

# %%
y=df.iloc[0:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_trns=np.transpose(x)

# %%
a=np.linalg.inv(np.dot(x_trns,x))

# %%
a.shape
# Out:
# (4, 4)

# %%
b= np.dot(x_trns,y)

# %%
b.shape
# Out:
# (4,)

# %%
b
# Out:
# array([  2804.5 , 482108.34,  74126.39,  90851.03])

# %%
a
# Out:
# array([[ 3.42444998e-02, -9.35348333e-05, -3.92647297e-04,
#         -2.08036831e-04],
#        [-9.35348333e-05,  6.84890750e-07, -1.57355890e-07,
#         -1.14959987e-07],
#        [-3.92647297e-04, -1.57355890e-07,  2.61016474e-05,
#         -6.26574016e-06],
#        [-2.08036831e-04, -1.14959987e-07, -6.26574016e-06,
#          1.21328472e-05]])

# %%
beta=np.matmul(a ,b)

# %%
beta
# Out:
# array([ 2.93888937e+00,  4.57646455e-02,  1.88530017e-01, -1.03749304e-03])

# %%
y.shape
# Out:
# (200,)

# %%
x
# Out:
# array([[  1. , 230.1,  37.8,  69.2],
#        [  1. ,  44.5,  39.3,  45.1],
#        [  1. ,  17.2,  45.9,  69.3],
#        [  1. , 151.5,  41.3,  58.5],
#        [  1. , 180.8,  10.8,  58.4],
#        [  1. ,   8.7,  48.9,  75. ],
#        [  1. ,  57.5,  32.8,  23.5],
#        [  1. , 120.2,  19.6,  11.6],
#        [  1. ,   8.6,   2.1,   1. ],
#        [  1. , 199.8,   2.6,  21.2],
#        [  1. ,  66.1,   5.8,  24.2],
#        [  1. , 214.7,  24. ,   4. ],
#        [  1. ,  23.8,  35.1,  65.9],
#        [  1. ,  97.5,   7.6,   7.2],
#        [  1. , 204.1,  32.9,  46. ],
#        [  1. , 195.4,  47.7,  52.9],
#        [  1. ,  67.8,  36.6, 114. ],
#        [  1. , 281.4,  39.6,  55.8],
#        [  1. ,  69.2,  20.5,  18.3],
#        [  1. , 147.3,  23.9,  19.1],
#        [  1. , 218.4,  27.7,  53.4],
#        [  1. , 237.4,   5.1,  23.5],
#        [  1. ,  13.2,  15.9,  49.6],
#        [  1. , 228.3,  16.9,  26.2],
#        [  1. ,  62.3,  12.6,  18.3],
# ...

# %%
b0,b1,b2,b3=beta

# %%
b1
# Out:
# 0.04576464545539764

# %%
ypredict=b0*1+b1*23.8+b2*35.1+b3*65.9

# %%
ypredict
# Out:
# 10.577120733627678

# %%
y.shape
# Out:
# (200,)

# %%
y_pre=np.dot(x,beta)

# %%
y_pre
# Out:
# array([20.52397441, 12.33785482, 12.30767078, 17.59782951, 13.18867186,
#        12.47834763, 11.72975995, 12.12295317,  3.72734086, 12.55084872,
#         7.0322992 , 17.28512918, 10.57712073,  8.82630048, 18.43436638,
#        20.81929952, 12.82365674, 23.22495716,  9.95168206, 14.16607293,
#        18.10076728, 14.7405382 ,  6.4891503 , 16.5459329 ,  8.14651887,
#        15.6100386 , 14.98951429, 17.05167344, 19.41053803,  9.14402389,
#        21.6339338 , 11.3460929 ,  7.63888314, 18.86426829,  7.57483051,
#        17.00682618, 23.40590052, 15.62347779,  9.90868103, 20.44761039,
#        16.37766467, 17.2959832 , 21.59580326, 13.96385684,  8.88787996,
#        15.16152314,  8.87338673, 21.7226299 , 16.26362018,  8.1681656 ,
#        12.63121132,  9.33981296, 20.66297563, 19.94469957, 20.37443008,
#        21.2926106 ,  8.52771254, 12.77458802, 21.89805198, 18.13348698,
#         5.74215558, 22.89067208, 16.78426073, 13.21069202, 16.97773556,
# ...

# %%
y_pre.shape
# Out:
# (200,)

# %%
x_1=df[['TV','Radio','Newspaper']]
y_1=df['Sales']
#y_pre=b0+b2*x_1
plt.plot(x_1,y_1,'o')
plt.plot()
plt.grid()
plt.show()
